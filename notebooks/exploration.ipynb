# %% [markdown]
# # Exploration notebook
#
# Quick interactive sandbox for looking at catalog / running a solver / inspecting results.

# %%
import sys, pathlib
sys.path.insert(0, str(pathlib.Path.cwd().parent))

from src.data_ingestion.food_catalog import build_food_catalog
from src.data_ingestion.workouts import load_sample_workouts
from src.experiments.instance_generator import generate_user, InstanceParams
from src.solvers.joint_cpsat import JointCPSATSolver
from src.visualization.schedule_view import render_schedule_to_figure

foods = build_food_catalog()
workouts = load_sample_workouts()
user = generate_user('balanced', InstanceParams(seed=1921))

solver = JointCPSATSolver(time_limit_s=15)
result = solver.solve(user, foods, workouts)
print(result.status, result.runtime_s)
if result.plan:
    fig, _ = render_schedule_to_figure(result.plan)
    fig
